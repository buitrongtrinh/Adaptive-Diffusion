# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd ./drive/MyDrive/AdaptiveDiffusion
# Out:
# /content/drive/MyDrive/AdaptiveDiffusion

# %%
# !pip install torchprofile datasets torchmetrics dominate clean-fid gradio

# %%
# %cd examples/AdaptiveDiffusion
# Out:
# /content/drive/MyDrive/AdaptiveDiffusion/examples/AdaptiveDiffusion

# %%
# !python demo_colab.py
# Out:
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://1fc1cfb8c2f4703ea6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2025-12-05 13:05:12.197437: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764939912.234892   18707 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764939912.246473   18707 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
